# %% [markdown]
# # Polynomial Regression Assignment

# %%
import numpy as np
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model, preprocessing
import numpy.polynomial.polynomial as poly
# %matplotlib inline

# %% [markdown]
# # Importing Data
# Import data from poly_regression.csv

# %%
# Run the code cell
df = pd.read_csv('poly_regression.csv')
data = df.values
X = data[:,0]
Y = data[:,1]
X = X.reshape(X.shape[0],1)
Y = Y.reshape(Y.shape[0],1)

# %% [markdown]
# # Training and Test Set
# Divide the dataset approximately into 2 equal parts : training and test set.

# %%
X_tr = X[0:100,0]
Y_tr = Y[0:100,0]
X_test = X[100:200,0]
Y_test = Y[100:200,0]

# %% [markdown]
# # Plotting Dataset

# %%
# Write code to plot the dataset.
plt.scatter(X_tr, Y_tr, c = 'g', s = 2)
plt.scatter(X_test,Y_test, c = 'r', s=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title("Training Data & test Data")
# Out:
# Text(0.5,1,'Training Data & test Data')

# %% [markdown]
# # Model Selection.
# Write code to obtain polynomial regression models of different orders starting from linear regression i.e. degree = 1 to higher degree models like degree = 2 to 10. Find training and test error for every order and plot these errors v/s degree. Select the order that fits the data best based on low training and test error. You can use poly.polyval method from numpy to find coefficients of the different models.

# %%
trError = []
tstError = []

for i in range(1,11): # i is the degree of the model
    
    print("Degree: " + str(i))
    
    beta = poly.polyfit(X_tr,Y_tr,i)
    yhat = poly.polyval(X_test,beta)
    tstError.append(np.sum((Y_test - yhat)**2)/ (2 * Y_test.shape[0]))
    
    
    yhat_train = poly.polyval(X_tr,beta)
    trError.append(np.sum(np.square(Y_tr - yhat_train)) / (2 * Y_tr.shape[0]))
    
    plt.scatter(X_tr,Y_tr,c ='g',s=1)
    plt.scatter(X_tr,yhat_train, c='b',s=1)
    plt.xlabel('X_train')
    plt.xlim([-1.5,1.5])

    plt.show()
# Out:
# Degree: 1
# Degree: 2
# Degree: 3
# Degree: 4
# Degree: 5
# Degree: 6
# Degree: 7
# Degree: 8
# Degree: 9
# Degree: 10

# %%
degree = np.array(range(1,11))
plt.plot(degree,tstError,'.-',c='b')
plt.plot(degree,trError,'.-',c='g')
plt.xlabel('Degree')
plt.title('Degree vs Tst Error & Training Error')
# Out:
# Text(0.5,1,'Degree vs Tst Error & Training Error')
